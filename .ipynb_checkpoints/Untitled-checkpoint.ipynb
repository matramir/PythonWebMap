# %%
import pandas as pd
data = pd.read_csv("volcano_db.csv", encoding = "ISO-8859-1")
for values in ("Number", "Region", "Country", "Type", "Status", "Last Known"):
    data = data.drop(values,1)
data[340:370]
# Out:
#                 Volcano Name  Latitude  Longitude    Elev
# 340                    Dofen     9.350     40.130  1151.0
# 341               Doma Peaks    -5.900    143.150  3568.0
# 342                   Domuyo   -36.630    -70.420  4709.0
# 343  Don Joao de Castro Bank    38.230    -26.630   -14.0
# 344               Dona Juana     1.470    -76.920  4150.0
# 345                  Dotsero    39.650   -107.030  2230.0
# 346                  Douglas    58.870   -153.550  2140.0
# 347            Doyo Seamount    27.683    140.800  -860.0
# 348                    Dubbi    13.580     41.808  1625.0
# 349                   Dukono     1.680    127.880  1185.0
# 350             Duncan Canal    56.500   -133.100    15.0
# 351       Durango Volc Field    24.150   -104.450  2075.0
# 352                   Dutton    55.180   -162.270  1506.0
# 353               Dzenzursky    53.637    158.922  2155.0
# 354                    E-san    41.800    141.170   618.0
# ...

# %%
data["Volcano Name"].str.replace("'","")
# Out:
# 0                       Abu
# 1                Acamarachi
# 2                Acatenango
# 3           Acigol-Nevsehir
# 4                     Adams
# 5                   Adatara
# 6                      Adwa
# 7                    Afdera
# 8           Agmagan-Karadag
# 9                   Agrigan
# 10                     Agua
# 11              Agua de Pau
# 12                 Aguilera
# 13                    Agung
# 14                     Ahyi
# 15            Akademia Nauk
# 16            Akademia Nauk
# 17                    Akagi
# 18                     Akan
# 19                  Akhtang
# 20        Akita-Komaga-take
# 21          Akita-Yake-yama
# 22             Akuseki-jima
# 23             Akuseki-jima
# 24                   Akutan
# 25                    Alaid
# 26                 Alamagan
# 27                   Alayta
# 28            Albano, Monte
# 29           Alcedo, Volcan
#                ...
# 1541               Yanteles
# 1542        Yanteles, Cerro
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1571, step=1)

# %%
import numpy as np
intervals = np.arange(0, data.index.max(), 50)
intervals[-1]
# Out:
# 1550

# %%
help(folium.Icon())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-009a236b7418> in <module>()
# ----> 1 help(folium.Icon)
#
# NameError: name 'folium' is not defined
